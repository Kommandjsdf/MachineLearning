# %% [markdown]
# <a href="https://colab.research.google.com/github/Kommandjsdf/MachineLearning/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D1%96%D0%B7%D0%B0%D1%82%D0%BE%D1%80_%D1%84%D1%96%D0%BB%D1%8C%D0%BC%D1%96%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
url = "movies_metadata.csv" #The url of the file with the table

df = pd.read_csv(url) #Make the table a dataframe

df.head() #Display first 5 rows of the dataframe
# Out:
# /tmp/ipython-input-2140282076.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url) #Make the table a dataframe
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
df.info() #Display some infomation about the different columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.describe() #Display some properties of the dataframe
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# Попередня обробка та очищення даних

# %%
df.isnull().sum() #Shows how many null values are in each column
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.dropna(inplace=True) #Removes all null cells
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 693 entries, 9 to 45029
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  693 non-null    object
#  1   belongs_to_collection  693 non-null    object
#  2   budget                 693 non-null    object
#  3   genres                 693 non-null    object
#  4   homepage               693 non-null    object
#  5   id                     693 non-null    object
#  6   imdb_id                693 non-null    object
#  7   original_language      693 non-null    object
#  8   original_title         693 non-null    object
#  9   overview               693 non-null    object
#  10  popularity             693 non-null    object
#  11  poster_path            693 non-null    object
#  12  production_companies   693 non-null    object
#  13  production_countries   693 non-null    object
# ...

# %%
# df['column_name'].fillna("чим заповнюємо", inplace=True)
# df['column_name'].fillna(df['column_name'].mean(), inplace=True)

df['homepage'].fillna("with out link", inplace=True) #Replaces all null cells' values

# movies_df.fillna({movies_df['homepage']:"with out link"}, inplace=True)
# Out:
# /tmp/ipython-input-3904111063.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['homepage'].fillna("with out link", inplace=True) #Replaces all null cells' values

# %%
df.info() #Shows the information about the columns after the operations above
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 693 entries, 9 to 45029
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  693 non-null    object
#  1   belongs_to_collection  693 non-null    object
#  2   budget                 693 non-null    object
#  3   genres                 693 non-null    object
#  4   homepage               693 non-null    object
#  5   id                     693 non-null    object
#  6   imdb_id                693 non-null    object
#  7   original_language      693 non-null    object
#  8   original_title         693 non-null    object
#  9   overview               693 non-null    object
#  10  popularity             693 non-null    object
#  11  poster_path            693 non-null    object
#  12  production_companies   693 non-null    object
#  13  production_countries   693 non-null    object
# ...

# %%
df.head() #Shoes the first 5 rows after the operations
# Out:
#      adult                              belongs_to_collection    budget  \
# 9    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 68   False  {'id': 43563, 'name': 'Friday Collection', 'po...   3500000
# 69   False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 153  False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...   2000000
# 178  False  {'id': 286162, 'name': 'Power Rangers Collecti...  15000000
#
#                                                 genres  \
# 9    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                      [{'id': 35, 'name': 'Comedy'}]
# 69   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                     [{'id': 35, 'name': 'Comedy'}]
# 178  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage     id    imdb_id  \
# 9         http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# ...

# %%
df['release_year'] = pd.to_datetime(df['release_date']).dt.year #Adds a column "release_year"

# %%
df.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 9    False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 68   False  {'id': 43563, 'name': 'Friday Collection', 'po...   3500000
# 69   False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 153  False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...   2000000
# 178  False  {'id': 286162, 'name': 'Power Rangers Collecti...  15000000
#
#                                                 genres  \
# 9    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 68                      [{'id': 35, 'name': 'Comedy'}]
# 69   [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 153                     [{'id': 35, 'name': 'Comedy'}]
# 178  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                               homepage     id    imdb_id  \
# 9         http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# ...

# %%
df[['release_date', 'release_year']] #Shows just the columns release_date and release_year
# Out:
#       release_date  release_year
# 9       1995-11-16          1995
# 68      1995-04-26          1995
# 69      1996-01-19          1996
# 153     1995-09-15          1995
# 178     1995-06-30          1995
# ...            ...           ...
# 44274   2017-07-11          2017
# 44674   2017-03-17          2017
# 44821   2000-07-08          2000
# 44842   2017-06-21          2017
# 45029   2017-05-12          2017
#
# [693 rows x 2 columns]

# %%
def extract_genres(genres_str: str) -> list[str]:
  try:
    genres = ast.literal_eval(genres_str)
    return [genre["name"] for genre in genres]
  except ValueError:
    return []

# %%
try:
  df['genres'] = df['genres'].apply(extract_genres)
except TypeError:
  df['genres'] = []

# %%
genre_counts = df['genres'].value_counts() #Counts how many movies there are with every genre combination
print(genre_counts) #Prints it
# Out:
# genres
# [Comedy]                                          37
# [Adventure, Action, Thriller]                     22
# [Horror, Thriller]                                17
# [Horror]                                          15
# [Documentary]                                     13
#                                                   ..
# [Family, Comedy, Animation, Adventure]             1
# [Family, Fantasy, Music, Animation]                1
# [Action, Animation, Adventure, Family, Comedy]     1
# [Drama, Science Fiction, War]                      1
# [Action, Science Fiction, Thriller, Adventure]     1
# Name: count, Length: 333, dtype: int64

# %%
df.fillna({'budget': 0, 'revenue': 0}, inplace=True)

df['budget'] = pd.to_numeric(df['budget'], errors='coerce')

df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')

df['profit'] = df['revenue'] - df['budget']

df['profit']
# Out:
# 9        294194034.0
# 68        24715918.0
# 69         6836616.0
# 153        -725000.0
# 178       51000000.0
#             ...
# 44274    217907963.0
# 44674            0.0
# 44821     52411275.0
# 44842    344942143.0
# 45029            0.0
# Name: profit, Length: 693, dtype: float64

# %%
genres_exploded = df[['title', 'release_date', 'budget', 'revenue', 'genres']].explode('genres')
genre_count = genres_exploded['genres'].value_counts()

plt.figure(figsize=(10, 6))

sns.barplot(x = genre_count.index, y = genre_count.values)

plt.title("Film genres")
plt.xlabel("Genre")
plt.ylabel("Amount of films")

plt.xticks(rotation=45)

plt.tight_layout()
